# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite", echo=False)

# %% [markdown]
# # Explore Database

# %%
#Inspector Gadget
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
# Get a list of column names and types
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c["type"])
    
# columns
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Get a list of column names and types
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c["type"])
    
# columns
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# reflect an existing database into a new model
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
# reflect the tables and view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table by establishing variables
measurements = Base.classes.measurement
stations = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Last date = most recent date (using order by desc)
recent_date = session.query(measurements.date).order_by(measurements.date.desc()).first()
print(recent_date)
# Out:
# ('2017-08-23',)

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database.
# Date 1 year ago from recent_date, the last date in data set.
year_ago = dt.date(2017,8,23) - dt.timedelta(days=365)
year_ago
# Out:
# datetime.date(2016, 8, 23)

# %%
# Perform a query to retrieve the data and precipitation scores
session.query(measurements.date, measurements.prcp).\
    filter(measurements.date >= year_ago).all()
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
last_year = session.query(measurements.date, measurements.prcp).\
    filter(measurements.date >= year_ago).all()

for date in last_year:
    print(date)
# Out:
# ('2016-08-23', 0.0)
# ('2016-08-24', 0.08)
# ('2016-08-25', 0.08)
# ('2016-08-26', 0.0)
# ('2016-08-27', 0.0)
# ('2016-08-28', 0.01)
# ('2016-08-29', 0.0)
# ('2016-08-30', 0.0)
# ('2016-08-31', 0.13)
# ('2016-09-01', 0.0)
# ('2016-09-02', 0.0)
# ('2016-09-03', 0.0)
# ('2016-09-04', 0.03)
# ('2016-09-05', None)
# ('2016-09-06', None)
# ('2016-09-07', 0.05)
# ('2016-09-08', 0.0)
# ('2016-09-09', 0.03)
# ('2016-09-10', 0.0)
# ('2016-09-11', 0.05)
# ('2016-09-12', 0.0)
# ('2016-09-13', 0.02)
# ('2016-09-14', 1.32)
# ('2016-09-15', 0.42)
# ('2016-09-16', 0.06)
# ('2016-09-17', 0.05)
# ('2016-09-18', 0.0)
# ('2016-09-19', 0.0)
# ('2016-09-20', 0.0)
# ('2016-09-21', 0.0)
# ('2016-09-22', 0.02)
# ('2016-09-23', 0.0)
# ('2016-09-24', 0.0)
# ('2016-09-25', 0.0)
# ('2016-09-26', 0.06)
# ('2016-09-27', 0.02)
# ('2016-09-28', 0.0)
# ('2016-09-29', 0.0)
# ('2016-09-30', 0.0)
# ('2016-10-01', 0.0)
# ('2016-10-02', 0.0)
# ('2016-10-03', 0.0)
# ('2016-10-04', 0.0)
# ('2016-10-05', 0.0)
# ...

# %%
# Sort the dataframe by date
prcp_df = pd.DataFrame(last_year,columns = ['date', 'prcp'])
prcp_df.set_index('date', inplace=True)
prcp_df = prcp_df.sort_values(['date'])
prcp_df.head()
# Out:
#             prcp
# date
# 2016-08-23  0.00
# 2016-08-23   NaN
# 2016-08-23  1.79
# 2016-08-23  0.05
# 2016-08-23  0.15

# %%
# Use Pandas Plotting with Matplotlib to plot the data

panda_bar_plot = prcp_df.plot.bar(figsize=(12,8), width=18)
plt.title("Daily Precipitation (8.23.2016 - 8.23.2017)",fontsize=14)
plt.xlabel("Date",fontsize=10)
plt.ylabel("Precipitation",fontsize=10)
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
summary = prcp_df["prcp"].describe()
stats = pd.DataFrame(summary)
stats
# Out:
#               prcp
# count  2021.000000
# mean      0.177279
# std       0.461190
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
total_stations = session.query(stations).filter(stations.id).count()
total_stations
# Out:
# 9

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
same_id = session.query(measurements, stations).filter(measurements.id == stations.id).limit(10).all()

for record in same_id:
    (measurements,stations) = record
    print(measurements.id, stations.id)

# %%
active_stations = session.query(measurements.station, func.count(measurements.station)).\
    groupby(measurements.station).\
    order_by(func.count(measurements.station).desc()).all()

active_stations

# %%
# Create query to find the most active stations 
active_stations = session.query(measurements.station.name, func.count(measurements.prcp).\
    groupby(measurements.station.name).orderby(func.count(measurements.prcp).desc()).first()
most_active_station = active_stations[0]
most_active_station

# %%
# Join data from two tables together in one dataset
sel = [stations.name,
       func.count(stations.id),
       func.min(measurments)
      ]
most_active = session.query(*sel).\
    filter(func.count(stations.station.distinct())).\
    group_by(measurements.station).\
    order_by(func.count(stations.station.distinct()).all()
may_averages

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
